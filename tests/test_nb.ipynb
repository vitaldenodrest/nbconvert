# %% [markdown]
# # I am notebook

# %% [markdown]
# ## I have md cells
# With text and LaTeX equations
# $$\cos{\frac{\pi}{2}} = 0$$

# %%
# I even have python code with prints
print(3+1)

# %%
# IPython display instructions
from IPython import display as disp
disp.display(8)

# %%
# Matplotlib figures
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot([0, 1, 2, 3], [1, 1.1, 1.2, 1.3])

# %%
# SymPy code
import sympy as sp
w = sp.symbols('\omega')
disp.display(w)
